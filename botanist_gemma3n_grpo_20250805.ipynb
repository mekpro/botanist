# %% [markdown]
# # Botanist GRPO Training - Visual Flower Description
#
# This notebook fine-tunes a Gemma-3n model using GRPO (Generative Reinforcement Learning from Preference Optimization) to improve botanical descriptions of flower images.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --upgrade --force-reinstall bitsandbytes accelerate xformers==0.0.31.post1 peft  triton cut_cross_entropy unsloth_zoo unsloth torchvision
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" huggingface_hub hf_transfer together cerebras_cloud_sdk groq
# !pip install --upgrade --force-reinstall transformers
# !pip install --no-deps --upgrade timm trl==0.19.1 # Only for Gemma 3N
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting accelerate
#   Downloading accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting xformers==0.0.31.post1
#   Downloading xformers-0.0.31.post1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Collecting peft
#   Downloading peft-0.17.0-py3-none-any.whl.metadata (14 kB)
# Collecting triton
#   Downloading triton-3.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting cut_cross_entropy
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting unsloth_zoo
#   Downloading unsloth_zoo-2025.8.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting unsloth
#   Downloading unsloth-2025.8.1-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.5 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting numpy (from xformers==0.0.31.post1)
#   Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.9 MB/s eta 0:00:00
# Collecting torch==2.7.1 (from xformers==0.0.31.post1)
#   Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting filelock (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton
#   Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting setuptools>=40.8.0 (from triton)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil (from accelerate)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate)
#   Downloading huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting transformers (from peft)
#   Downloading transformers-4.54.1-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.6 MB/s eta 0:00:00
# Collecting tqdm (from peft)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.0 MB/s eta 0:00:00
# Collecting tyro (from unsloth_zoo)
#   Downloading tyro-0.9.27-py3-none-any.whl.metadata (11 kB)
# Collecting datasets<4.0.0,>=3.4.1 (from unsloth_zoo)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentencepiece>=0.2.0 (from unsloth_zoo)
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting wheel>=0.42.0 (from unsloth_zoo)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting trl!=0.15.0,!=0.19.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth_zoo)
#   Downloading trl-0.20.0-py3-none-any.whl.metadata (11 kB)
# Collecting protobuf (from unsloth_zoo)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting hf_transfer (from unsloth_zoo)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting pillow (from unsloth_zoo)
#   Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting regex (from unsloth_zoo)
#   Downloading regex-2025.7.34-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.1 MB/s eta 0:00:00
# Collecting msgspec (from unsloth_zoo)
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting diffusers (from unsloth)
#   Downloading diffusers-0.34.0-py3-none-any.whl.metadata (20 kB)
# Collecting pyarrow>=15.0.0 (from datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading pandas-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.2 MB/s eta 0:00:00
# Collecting requests>=2.32.2 (from datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting xxhash (from datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch==2.7.1->xformers==0.0.31.post1)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub>=0.21.0->accelerate)
#   Downloading hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting tokenizers<0.22,>=0.21 (from transformers->peft)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting importlib_metadata (from diffusers->unsloth)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting docstring-parser>=0.15 (from tyro->unsloth_zoo)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=11.1.0 (from tyro->unsloth_zoo)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting shtab>=1.5.6 (from tyro->unsloth_zoo)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting typeguard>=4.0.0 (from tyro->unsloth_zoo)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1.0->tyro->unsloth_zoo)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=11.1.0->tyro->unsloth_zoo)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch==2.7.1->xformers==0.0.31.post1)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers->unsloth)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.7.1->xformers==0.0.31.post1)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading multidict-6.6.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 7.0 MB/s eta 0:00:00
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth_zoo)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->datasets<4.0.0,>=3.4.1->unsloth_zoo)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading xformers-0.0.31.post1-cp39-abi3-manylinux_2_28_x86_64.whl (117.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 MB 18.5 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 2.0 MB/s eta 0:00:00
# Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/8.9 MB ? eta -:--:--

# %%
# !export HF_HUB_ENABLE_HF_TRANSFER=1
from google.colab import drive
from huggingface_hub import HfApi,login

import os
from google.colab import userdata
drive.mount('/content/drive')
output_dir = f"/content/drive/MyDrive/colab_output/qwen-botanist"
os.makedirs(output_dir, exist_ok=True)
HF_TOKEN=userdata.get('HF_TOKEN')
login(token=HF_TOKEN)
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import json
import torch
import re
import numpy as np
from typing import List, Dict, Tuple, Optional
from dataclasses import dataclass
import pandas as pd
from tqdm import tqdm

# Unsloth and TRL imports
from unsloth import FastLanguageModel
from unsloth import is_bf16_supported
from datasets import load_dataset, Dataset
from trl import GRPOConfig, GRPOTrainer
from transformers import TrainingArguments
from google.colab import userdata

# Together AI for reward evaluation

import os
#from cerebras.cloud.sdk import Cerebras
#from groq import Groq
#client = Cerebras(api_key=userdata.get("CEREBRAS_API_KEY"))
#client = Groq(api_key=userdata.get("GROQ_API_KEY"))
#together_client = Together(api_key=userdata.get("TOGETHER_API_KEY"))
from openai import OpenAI
client = OpenAI(base_url="https://openrouter.ai/api/v1", api_key=userdata.get("OPENROUTER_API_KEY") )


torch.manual_seed(42)
np.random.seed(42)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# ## 2. Configuration

# %%
# Model configuration
MODEL_NAME =  "mekpro/gemma-3n-botanist-observe6-merged" # our model !
#MODEL_NAME = "unsloth/gemma-3n-E2B-it-unsloth-bnb-4bit"

MAX_SEQ_LENGTH = 512 # Adjust based on your needs
MAX_NEW_TOKENS = 350
MAX_PROMPT_LENGTH = 150

LOAD_IN_4BIT = False

# PEFT configuration
LORA_R = 32
LORA_ALPHA = 64
LORA_DROPOUT = 0.1
TARGET_MODULES = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]

# Training configuration
BATCH_SIZE = 32
GRADIENT_ACCUMULATION_STEPS = 1
LEARNING_RATE = 1e-5
NUM_TRAIN_EPOCHS = 1
WARMUP_STEPS = 20
LOGGING_STEPS = 1
SAVE_STEPS = 100
OUTPUT_DIR = output_dir

# GRPO configuration
NUM_GENERATION_PER_PROMPT = 8  # Number of responses to generate per prompt
TEMPERATURE = 1.1
TOP_P = 0.9

# Reward weights
BOTANIST_REWARD_WEIGHT = 0.5
FORMAT_REWARD_WEIGHT = 0.15
SPECIES_INFLORESCENCETYPE_WEIGHT = 0.35


# API configuration

# Dataset configuration
DATASET_NAME = "mekpro/plantnet300k_observe"
MAX_SAMPLES = 4000  # Set to a number to limit dataset size for testing

# %% [markdown]
# ## 3. Load Model and Tokenizer

# %%
# Load model and tokenizer
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=MODEL_NAME,
    max_seq_length=MAX_SEQ_LENGTH,
    load_in_4bit=LOAD_IN_4BIT,
    dtype=torch.bfloat16 if is_bf16_supported() else torch.float16,
)
model.generation_config.cache_implementation=None
# Configure PEFT

model = FastLanguageModel.get_peft_model(
    model,
    r=LORA_R,
    target_modules=TARGET_MODULES,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    bias="none",
    task_type="CAUSAL_LM",
    use_rslora=False,
    loftq_config=None,
)


# Set padding token if not set
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
# Out:
# ==((====))==  Unsloth 2025.7.11: Fast Gemma3N patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Gemma3N does not support SDPA - switching to eager!
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.1.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth: Making `model.base_model.model.model.language_model` require gradients

# %% [markdown]
# ## 4. Load and Prepare Dataset

# %%
# Load dataset
dataset = load_dataset(DATASET_NAME, split="train")

# Extract unique species
species_list = dataset["species"]
dataset = dataset.shuffle(seed=42)
unique_species = list(set(species_list))
print(f"Total unique species: {len(unique_species)}")

# Limit dataset size if specified
if MAX_SAMPLES:
    dataset = dataset.select(range(min(MAX_SAMPLES, len(dataset))))
    print(f"Limited dataset to {len(dataset)} samples")

# Define the instruction prompt
INSTRUCTION_PROMPT = '''As a botanist, describe its visual features and species_name in JSON format. {'color':'', 'inflorescencetype':'', 'inflorescence_description':'','flower_arrangement':'', 'flower_density':'', 'species':'', 'family':'', 'genus':''}'''
dataset = dataset.map(lambda x: {
    "prompt" : [
        {"role": "system" , "content" : INSTRUCTION_PROMPT},
        {"role": "user",    "content" : "Describe "+x["species"]}
    ]
})
#print(f"Prepared {len(dataset)} prompts")
#print(dataset[0])

#write function to make a dict {'species' : 'inflorescencetype'} from dataset
def get_species_inflorescence_dict(dataset):
    species_inflorescence_dict = {}
    for example in dataset:
        species_inflorescence_dict[example['species']] = example['inflorescencetype']
    return species_inflorescence_dict
species_list = dataset["species"]
unique_species = list(set(species_list))
print("unique after sample: %d" %len(unique_species))
species_inflorescence_data = get_species_inflorescence_dict(dataset)
print(species_inflorescence_data)
# Out:
# Total unique species: 381
# Limited dataset to 4000 samples
# unique after sample: 342
# {'Hypericum humifusum': 'Cyme', 'Secale cereale': 'Spike', 'Calendula stellata': 'Capitulum (Head)', 'Smilax aspera': 'Panicle of Umbels', 'Phyllanthus amarus': 'Axillary cyme', 'Lupinus albus': 'Terminal raceme', 'Zamioculcas zamiifolia': 'Spadix and Spathe', 'Hippophae rhamnoides': 'Axillary Cluster', 'Tradescantia pallida': 'Terminal cymes', 'Hebe salicifolia': 'Raceme', 'Cucurbita maxima': 'Solitary', 'Casuarina equisetifolia': 'Catkin', 'Moehringia trinervia': 'Cyme', 'Tagetes erecta': 'Capitulum', 'Melilotus indicus': 'Raceme', 'Lupinus angustifolius': 'Raceme', 'Phedimus aizoon': 'Cyme (Corymb-like)', 'Carthamus tinctorius': 'Capitulum', 'Epipactis helleborine': 'Raceme', 'Gynura procumbens': 'Capitulum', 'Hyoscyamus niger': 'Scorpioid cyme', 'Lactuca sativa': 'Capitulum', 'Ophrys lutea': 'Spike', 'Acalypha hispida': 'Catkin', 'Pelargonium peltatum': 'Pseudo-umbel', 'Sedum pachyphyllum': 'Terminal Cyme', 'Casuarina cunninghamiana': 'Male Catkin', 'Punica granatum': 'Solitary', 'Nymphaea alba': 'Solitary', 'Chaerophyllum hirsutum': 'Compound Umbel', 'Hypericum perfoliatum': 'Cyme', 'Vaccaria hispanica': 'Dichasial cyme', 'Leersia oryzoides': 'Panicle', 'Carthamus mitissimus': 'Capitulum', 'Cytinus hypocistis': 'Dense spike', 'Cenchrus longisetus': 'Spicate panicle', 'Sedum album': 'Cyme', 'Lactuca saligna': 'Panicle of capitula', 'Geropogon hybridus': 'Capitulum (Head)', 'Oncostema peruviana': 'Solitary', 'Barbarea verna': 'Raceme', 'Lavandula angustifolia': 'Spike of verticillasters', 'Hypericum hircinum': 'Terminal cyme', 'Ophrys tenthredinifera': 'Spike', 'Sedum hispanicum': 'Cyme', 'Anemone coronaria': 'Solitary', 'Phalaris coerulescens': 'Compact spike-like panicle', 'Cirsium rivulare': 'Capitulum', 'Pelargonium odoratissimum': 'Umbellate cyme', 'Acacia melanoxylon': 'Globular head', 'Acacia mearnsii': 'Globose head', 'Hyoseris radiata': 'Capitulum', 'Sedum cepaea': 'Paniculate cyme', 'Daphne mezereum': 'Axillary Clusters', 'Papaver dubium': 'Solitary', 'Lactuca serriola': 'Capitulum', 'Perovskia abrotanoides': 'Paniculate Spikes', 'Tradescantia cerinthoides': 'Cyme', 'Neotinea maculata': 'Spike', 'Butomus umbellatus': 'umbel', 'Lagenaria siceraria': 'Solitary (monoecious)', 'Althaea officinalis': 'Axillary clusters', 'Falcaria vulgaris': 'Compound Umbel', 'Thesium humifusum': 'Very sparse axillary flowers along stem', 'Erechtites hieraciifolius': 'Capitulum', 'Cereus jamacaru': 'solitary', 'Hyoscyamus albus': 'Scorpioid cyme', 'Hypericum androsaemum': 'Terminal cyme', 'Epipactis palustris': 'Raceme', 'Melilotus officinalis': 'Raceme', 'Lactuca muralis': 'Panicle', 'Vanilla planifolia': 'Raceme', 'Mercurialis perennis': 'Axillary cluster (female, developing fruit)', 'Tagetes minuta': 'Capitulum', 'Papaver somniferum': 'Solitary', 'Phalaris arundinacea': 'Panicle', 'Centranthus ruber': 'corymbose cyme', 'Cenchrus purpureus': 'Spike-like panicle', 'Tradescantia zebrina': 'Paired Cymes', 'Browallia americana': 'Solitary axillary or loose cyme', 'Daphne cneorum': 'Terminal cluster', 'Humulus lupulus': 'Strobile (female)', 'Cirsium heterophyllum': 'Capitulum', 'Gomphocarpus physocarpus': 'umbellate cyme', 'Acacia drepanolobium': 'Globular head', 'Cirsium eriophorum': 'Capitulum', 'Gynura aurantiaca': 'Capitulum', 'Acacia tortilis': 'Capitulum (globose head)', 'Sedum dendroideum': 'Terminal corymbose cyme', 'Tradescantia spathacea': 'Cyme enclosed by spathes', 'Hypericum hirsutum': 'Cyme', 'Phyllanthus tenellus': 'Axillary fascicle', 'Sedum sediforme': 'Terminal cyme', 'Trifolium incarnatum': 'Capitulum (Head)', 'Cirsium erisithales': 'Capitulum', 'Myosoton aquaticum': 'Dichasial Cyme', 'Pancratium maritimum': 'Umbel', 'Carthamus carduncellus': 'Capitulum', 'Adonis aestivalis': 'Solitary flower', 'Cucurbita pepo': 'Solitary, axillary', 'Adonis flammea': 'Solitary', 'Melilotus altissimus': 'Raceme', 'Lamium purpureum': 'Verticillaster', 'Sedum anglicum': 'Cyme', 'Pyracantha koidzumii': 'Corymb', 'Adonis annua': 'Solitary', ...

# %% [markdown]
# ## 5. Reward Functions

# %%
instruction_grade = '''
as a botanist professor, grade this observation of the species consistent with real data, give score 0-100.
- If can tell correct color of that species: give +20score, if similar: +10 score, if wrong : -10 score, if color not exists: -40 score
- If can tell inflorescencetype of that species, give +20 score, if wrong inflorescencetype: -10 score , if that inflorescencetype not exist:-20 score
- If can tell valid family of plant from species, + 10 score , if wrong -5 score, if family not valid plant family , -20 score
- If can tell correct flower_density+10 score,
- Other 40 score from visual description consistency, minus 20 score if have wrong grammar.
- If have other alphabet word in non-english appeared, minus 50 score
only reply score number 0-100 dont describe"},
'''
def botanist_rw(prompts: List[str], completions: List[str], **kwargs) -> List[float]:
    """
    Use LLM to evaluate botanical accuracy of the response.
    Returns a list of scores between 0 and 1.
    """
    rewards = []

    for prompt, response in zip(prompts, completions):

        eval_prompt = str(response[0]["content"])

        try:
            api_response = client.chat.completions.create(
                #model="Qwen/Qwen3-235B-A22B-Instruct-2507-tput",
                #model="qwen-3-235b-a22b-instruct-2507",
                model="qwen/qwen3-235b-a22b-2507:nitro",
                messages=[
                    {"role": "system", "content": instruction_grade},
                    {"role": "user", "content": eval_prompt}
                ],
                temperature=0.1,
                max_completion_tokens=10,
            )

            # Extract score from response
            score_text = api_response.choices[0].message.content.strip()

            # Extract number from response
            score_match = re.search(r'\d+', score_text)
            if score_match:
                score = float(score_match.group())
                score = min(max(score, 0), 100) / 100.0  # Normalize to 0-1
            else:

                score = 0.0

            output = response[0]["content"].replace("```json","").replace("\n","")

            print("%.2f : %s : %s " % (score,str(prompt[1]["content"]), output))


        except Exception as e:
            print(f"Error in botanist_reward: {e}")
            score = 0.0

        rewards.append(score * BOTANIST_REWARD_WEIGHT)  # Apply weight here

    return rewards

def format_rw(prompts: List[str], completions: List[str], **kwargs) -> List[float]:
    """
    Validate JSON format and required fields.
    Returns a list of scores between 0 and 1.
    """
    required_fields = { "color", "inflorescencetype", "inflorescence_description", "flower_arrangement", "flower_density", "species", "family", "genus"}

    rewards = []

    for r in completions:
        score = 100.0
        response = r[0]["content"]
        response = response.replace("```json","").replace("\n","").replace("```","")
        #print(response)

        try:
            # Try to parse JSON from the extracted text
            data = json.loads(response)
            # Check if it's a dictionary
            if not isinstance(data, dict):
                score = 0.0
            else:
                # Check for required fields
                present_fields = set(data.keys())

                # Deduct points for missing required fields
                missing_fields = required_fields - present_fields
                score -= len(missing_fields) * 10

                # Deduct points for extra fields
                extra_fields = present_fields - required_fields
                score -= len(extra_fields) * 20

        except json.JSONDecodeError:
            # Invalid JSON format
            score = 0.0
        except Exception as e:
            print(f"Error in format_reward: {e}")
            print(f"Response type: {type(response)}")
            print(f"Response content: {response}")  # This will help debug
            score = 0.0

        rewards.append(max(score, 0.0) / 100.0 * FORMAT_REWARD_WEIGHT)

    return rewards


#write reward function to check that try to make object jsonstring 'completions' (if fail score=0), check that object have 'species' key ,
# if content of species is a a substring of prompts , add score 0.5 ,
# if content of inflorescencetype is == species_inflorescence_data['species'], add score 0.5
# score * SPECIES_INFLORESCENCETYPE_WEIGHT , append to list  , return
#def species_inflorescencetype_reward_func((prompts: List[str], completions: List[str], **kwargs) -> List[float]:

def species_rw(prompts: List[str], completions: List[str], **kwargs) -> List[float]:
    rewards = []
    for prompt, response in zip(prompts, completions):
        score = 0.0
        response_text = response[0]["content"].replace("```json","").replace("\n","").replace("```","")

        try:
            data = json.loads(response_text)
            if "species" in data:
                # Check if species name is a substring of the prompt
                #print(type(data["species"]))
                #print(type(str(prompt[1])[-20:]))
                #print(type(species_inflorescence_data[data["species"]]))
                #print(prompt)
                #print(response)
                #print(data["species"] + " : " + str(prompt[1]["content"]) + " : " + species_inflorescence_data[data["species"]])
                if data["species"] in str(prompt[1]["content"]):
                    score += 0.5

                # Check if inflorescence type matches the data for the species
                if "inflorescencetype" in data and data["species"] in species_inflorescence_data:
                    if data["inflorescencetype"] == species_inflorescence_data[data["species"]]:
                        score += 0.5

        except json.JSONDecodeError:
            # Invalid JSON format
            score = 0.0
        except Exception as e:
            print(f"Error in species_inflorescencetype_reward_func: {e}")
            score = 0.0

        rewards.append(score * SPECIES_INFLORESCENCETYPE_WEIGHT)

    return rewards

# %% [markdown]
# ## 6. GRPO Configuration and Training

# %%
# Create training arguments
model.config.use_cache = False
training_args = GRPOConfig(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
    learning_rate=LEARNING_RATE,
    max_grad_norm=0.5,
    num_train_epochs=NUM_TRAIN_EPOCHS,
    warmup_steps=WARMUP_STEPS,
    logging_steps=LOGGING_STEPS,
    save_steps=SAVE_STEPS,
    save_total_limit=3,
    fp16=not is_bf16_supported(),
    bf16=is_bf16_supported(),
    gradient_checkpointing=False,
    optim="paged_adamw_8bit",
    seed=42,
      # GRPO specific
    num_generations=NUM_GENERATION_PER_PROMPT,
    temperature=TEMPERATURE,
    top_p=TOP_P,
    max_prompt_length=MAX_PROMPT_LENGTH,
    max_completion_length=MAX_NEW_TOKENS,
)

# Create GRPO trainer
trainer = GRPOTrainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    train_dataset=dataset,
    reward_funcs=[botanist_rw, format_rw, species_rw],
)

print("GRPO Trainer initialized successfully!")
# Out:
# GRPO Trainer initialized successfully!

# %% [markdown]
# ## 7. Training

# %%
torch._dynamo.config.cache_size_limit = 512  # Default is 64, increase as needed
# Start training
print("Starting GRPO training...")
trainer.train()

print("Training completed!")
# Out:
# 0.58 : Describe Vaccaria hispanica : {"color": "Vibrant scarlet-red with petals brown from inside in.** "inflorescencetype": "Solitary", "inflorescence_description": "Single flower on an long pedicel, arising from leaf axil.", "flower_arrangement": "Solitary terminal flowers, sometimes axillary.", "flower_density": "Typically scattered, not dense clumps of flowers.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.58 : Describe Vaccaria hispanica : {"color": "Vibrant magenta-pink", "inflorescencetype": "Dense terminal cyme", "inflorescence_description": "2-4 flowers in a compact, rounded cluster topping the fuzzy brown leaves.", "flower_arrangement": "A dense mat of bright flowers tightly packed on a short, slightly elongated stem.", "flower_density": "Dense", "species": "Fedia cornucopiae", "family": "Caprifoliaceae", "genus": "Fedia"}
# 0.45 : Describe Vaccaria hispanica : {"color": "Vibrant scarlet-red with petals visible on upper petals.", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower on an long pedicel (short) arising from leaf axil.", "flower_arrangement": "One flower per scape, arising from leaf axil, often detecals.", "flower_density": "Low (typically 2-4 flowers per spike)", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.45 : Describe Vaccaria hispanica : {"color": "Vibrant scarlet-red-mixed with mixed-female flowers from female flowers.", "inflorescencetype": "Pseudo-umbel", "inflorescence_description": "A large, well-formed pseudo-umbel with numerous flowers blooming simultaneously.", "flower_arrangement": "Flowers in a slightly elongated cluster, well-formed petals.", "flower_density": "Moderate", "species": "Pelargonium graveolobum", "family": "Geraniaceae", "genus": "Pelargonium"}
# 0.45 : Describe Vaccaria hispanica : {"color": "Vibrant scarlet-red with petals on a warm, autumnal backdrop.", "inflorescencetype": "Solitary", "inflorescence_description": "A single, large, terminal flower on a long, slender peduncle.", "flower_arrangement": "A solitary bloom, presented terminally, with petals reflexed slightly as age.", "flower_density": "A late-season cyme with flowers mixed-scale, from fresh to spent blooms.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Vaccaria hispanica : {"color": "Vibrant scarlet-red with petals on a warm, curved stem.", "inflorescencetype": "Solitary", "inflorescence_description": "A single, large, open flower is presented on a slender, erect peduncle.", "flower_arrangement": "Flower emerges singly from a leaf-like bract on a long peduncle.", "flower_density": "Low (but visually striking)", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.65 : Describe Vaccaria hispanica : {"color": "Vibrant scarlet-red with petals on a warm, autumnal backdrop.", "inflorescencetype": "Solitary", "inflorescence_description": "A single, large, terminal flower on a long, slender peduncle.", "flower_arrangement": "A solitary bloom, terminal or axillary.", "flower_density": "Low-growing, with flowers sparsely distributed along the plant's length.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Vaccaria hispanica : {"color": "Vibrant magenta-pink", "inflorescencetype": "Dense terminal cyme", "inflorescence_description": "2-7 flowers in a compact, rounded cluster at the stem's apex.", "flower_arrangement": "A dense magenta hue on petals with a detailed purple striation visible upon close blooming.", "flower_density": "Very dense", "species": "Fedia graciliflora", "family": "Caprifoliaceae", "genus": "Fedia"}
# 0.00 : Describe Egeria densa : {"color": "Slightly matted olive-green", "inflorescencetype": "Raceme", "inflorescence_description": "Less vibrant raceme, appearing slightly muted in diffuse light.", "flower_arrangement": "Whorled arrangement, potentially wiry or subdued.", "flower_density": "Vibrant flowers, but overall inf-root may be less vigorous.", "species": "Raceme", "family": "Raceme", "genus": "Raceme"}
# 0.65 : Describe Egeria densa : {"color": "Slightly muted yellow", "inflorescencetype": "Raceme", "inflorescence_description": "Erect, elongating raceme with across-7 petals.", "flower_arrangement": "Flowers sequentially along the raceme, opening sequentially from inner petals.", "flower_density": "Densely packed towards the apex.", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.85 : Describe Egeria densa : {"color": "Slightly wind-swept golden-yellow", "inflorescencetype": "CHead", "inflorescence_description": "Soft, less vivid heads, appearing slightly scattered along stems.", "flower_arrangement": "Clusters on stems, often with mature leaves mixed with fresh buds.", "flower_density": "Moderate, heads scattered stems, individual buds still buds.", "species": "Acacia longifolia", "family": "Fabaceae", "genus": "Acacia"}
# 0.10 : Describe Egeria densa : {"color": "Slightly muted grayish-green", "inflorescencetype": "Sarctica Reddish", "inflorescence_description": "Reddish showing a pigmentation within a darker, reddish_,$-[etalecum (head)", "flower_arrangement": "Sarctica, with some red petals showing fine dust.", "flower_density": "Sufficiently dense, reduced flowering space.", "species": "Adonis discolor", "family": "Papaveraceae", "genus": "Adonis"}
# 0.00 : Describe Egeria densa : {"color": "Slightly wet, fresh green-yellow", "inflorescencetype": "C headless", "inflorescence_description": "turgid, fresh green", "flower_arrangement": "D headless, reflexed on short pedicels, slightly wet.", "flower_density": "High, turgid appearance", "species": "Zheadless (Zanthoty intermorpho) " "family": "Zantheraceae", "genus": "Zanthoty"}
# 0.00 : Describe Egeria densa : {"color": "Slightly matted olive-green", "inflorescencetype": "Raceme", "inflorescence_description": "Moderately dense raceme, somewhat gappy.", "flower_arrangement": "Flowers closely spaced along the stem.", "flower_density": "High, but gaps visible.", "species": "Raceme rich florets.", "family": "Raceme", "genus": "Raceme"}
# 0.95 : Describe Egeria densa : {"color": "Slightly muted yellow", "inflorescencetype": "Raceme", "inflorescence_description": "Well-formed, elongated raceme, elongating in late season.", "flower_arrangement": "Flowers consistently spaced along the raceme, densely distributed.", "flower_density": "Dense, flowers appear consistently distributed along the raceme.", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.85 : Describe Egeria densa : {"color": "Slightly wet, fresh orange-yellow", "inflorescencetype": "Dense", "inflorescence_description": "Turgid, fresh cluster, appearing fresh", "flower_arrangement": "Tightly filled, usually upright, similar", "flower_density": "High, though slightly less open, fresh", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.25 : Describe Pelargonium graveolens : {"color": "Vibrant fuchsia-pink", "inflorescencetype": "Terminal cluster", "inflorescence_description": "Dense, rounded terminal clusters.", "flower_arrangement": "Flowers tightly grouped at stem tips.", "flower_density": "Very dense clusters", "species": "Fedia cumbosities", "family": "Caprifoliaceae", "genus": "Fedia"}
# 0.00 : Describe Pelargonium graveolens : {"color": "Vibrant fuchsia-pink", "inflorescencetype": "Terminal cluster", "inflorescence_description": "Dense, rounded terminal clusters.", "flower_arrangement": "Flowers tightly grouped at stem tips.", "flower_density": "Very dense clusters", "species": "Fruzikum maritimum", "family": "Lythraceae", "genus": "Fruzikum"}
# 0.85 : Describe Pelargonium graveolens : {"color": "Vibrant magenta-pink", "inflorescencetype": "Capitulum-globose head", "inflorescence_description": "2-4 dense, flower heads on long stalks, often elongated stems.", "flower_arrangement": "A compact, ovoid head with a slight green tint, possibly due to shade.", "flower_density": "High density", "species": "Cirsium digitum", "family": "Asteraceae", "genus": "Cirsium"}
# 0.95 : Describe Pelargonium graveolens : {"color": "Vibrant magenta-pink", "inflorescencetype": "Pseudo-umbel", "inflorescence_description": "2-4 flowers in a compact cluster on a sturdy stalk above the leaf petiole.", "flower_arrangement": "Flowers pseudo-umbel with a slightly airy, clearly separated flower pair.", "flower_density": "Moderate", "species": "Pelargonium graveolens", "family": "Geraniaceae", "genus": "Pelargonium"}
# 0.25 : Describe Pelargonium graveolens : {"color": "Vibrant fuchsia-pink", "inflorescencetype": "Terminal cluster", "inflorescence_description": "Dense, rounded terminal clusters.", "flower_arrangement": "Flowers tightly grouped at stem tips.", "flower_density": "Very dense clusters", "species": "Fursy fruit raceme", "family": "Rosaceae", "genus": "Fursy fruit raceme"}
# 0.45 : Describe Pelargonium graveolens : {"color": "Vibrant coral-pink", "inflorescencetype": "Terminal cluster", "inflorescence_description": "Clustered on a slightly robust, mature stem indicating favorable, moist conditions.", "flower_arrangement": "Flowers are tight, often cluster-arked, each on turg", "flower_density": "Dense", "species": "Fedia graciliflora", "family": "Caprifoliaceae", "genus": "Fedia"}
# 0.65 : Describe Pelargonium graveolens : {"color": "Vibrant magenta-pink", "inflorescencetype": "Pseudo-umbel", "inflorescence_description": "2-4 flowers in a compact cluster on a robust, leafless peduncle.", "flower_arrangement": "Flowers radiate from a central point, typical for a pseudo-umbel.", "flower_density": "Compact", "species": "Pelargonium graveolens", "family": "Geraniaceae", "genus": "Pelargonium"}
# 0.85 : Describe Pelargonium graveolens : {"color": "Vibrant fuchsia-pink", "inflorescencetype": "Terminal cluster", "inflorescence_description": "Dense, rounded terminal clusters.", "flower_arrangement": "Flowers tightly grouped at stem tips.", "flower_density": "Very dense clusters", "species": "Fuchsia striata", "family": "Caprifoliaceae", "genus": "Fuchsia"}
# 0.95 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often dense", "flower_arrangement": "Tightly clusters along the central axis", "flower_density": "Very dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense,Head-like raceme, often with dense purple tips.", "flower_arrangement": "Head-like clusters", "flower_density": "Very dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often slightly nodding by a gentle stem.", "flower_arrangement": "Sessile flowers densely clustered in whorls at nodes, typically long.", "flower_density": "High, often dense whorls", "species": "Trifolium micranthum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.35 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Vike", "inflorescence_description": "EDense, elongated spike like dense", "flower_arrangement": "Tightly cluster of flowers on spike", "flower_density": "Very dense", "species": "Erucastrum yellow", "family": "Brassicaceae", "genus": "Erucastrum"}
# 0.85 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense,Head-like raceme, typically 4-7", "flower_arrangement": "Head-like, slightly nodding, slightly nodding", "flower_density": "High, almost solid yellow", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense,Head-like raceme, long, slender raceme.", "flower_arrangement": "Tightly clusters of flowers, each with subtle yellow petals.", "flower_density": "Very dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.95 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often slightly nodding by a gentle stem.", "flower_arrangement": "Sessile flowers crowded in whorls at the upper stem, alternate leaf pairs.", "flower_density": "Dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.35 : Describe Trifolium repens : {"color": "Vibrant yellow", "inflorescencetype": "Vike", "inflorescence_description": "E-rect, slightly nodding spike, typically nodding.", "flower_arrangement": "Four flowers nodding in a slightly nodding head, slightly nodding.", "flower_density": "Dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
#     <div>
#
#       <progress value='940' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 940/1000 13:56:28 < 53:30, 0.02 it/s, Epoch 0.94/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / botanist_rw / mean</th>
#       <th>rewards / botanist_rw / std</th>
#       <th>rewards / format_rw / mean</th>
#       <th>rewards / format_rw / std</th>
#       <th>rewards / species_rw / mean</th>
#       <th>rewards / species_rw / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>0.290312</td>
#       <td>0.162853</td>
#       <td>107.218750</td>
#       <td>82.000000</td>
#       <td>139.000000</td>
#       <td>0.000000</td>
#       <td>107.218750</td>
#       <td>82.000000</td>
#       <td>139.000000</td>
#       <td>0.000000</td>
#       <td>0.137187</td>
#       <td>0.118709</td>
#       <td>0.131250</td>
#       <td>0.050402</td>
#       <td>0.021875</td>
#       <td>0.058802</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>0.362500</td>
#       <td>0.150240</td>
#       <td>108.687500</td>
#       <td>82.000000</td>
#       <td>149.000000</td>
#       <td>0.000000</td>
#       <td>108.687500</td>
#       <td>82.000000</td>
#       <td>149.000000</td>
#       <td>0.000000</td>
#       <td>0.189063</td>
#       <td>0.136183</td>
#       <td>0.140625</td>
#       <td>0.036890</td>
#       <td>0.032812</td>
#       <td>0.069398</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.256094</td>
#       <td>0.144731</td>
#       <td>112.750000</td>
#       <td>86.000000</td>
#       <td>298.000000</td>
#       <td>0.000000</td>
#       <td>112.750000</td>
#       <td>86.000000</td>
#       <td>298.000000</td>
#       <td>0.002495</td>
#       <td>0.119375</td>
#       <td>0.166563</td>
#       <td>0.131250</td>
#       <td>0.050402</td>
#       <td>0.005469</td>
#       <td>0.030936</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.192188</td>
#       <td>0.110640</td>
#       <td>130.906250</td>
#       <td>88.000000</td>
#       <td>350.000000</td>
#       <td>0.093750</td>
#       <td>108.241379</td>
#       <td>88.000000</td>
#       <td>127.000000</td>
#       <td>0.002193</td>
#       <td>0.059375</td>
#       <td>0.079755</td>
#       <td>0.121875</td>
#       <td>0.059484</td>
#       <td>0.010937</td>
#       <td>0.043039</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.450156</td>
#       <td>0.249967</td>
#       <td>106.312500</td>
#       <td>87.000000</td>
#       <td>134.000000</td>
#       <td>0.000000</td>
#       <td>106.312500</td>
#       <td>87.000000</td>
#       <td>134.000000</td>
#       <td>0.001985</td>
#       <td>0.200156</td>
#       <td>0.168420</td>
#       <td>0.140625</td>
#       <td>0.036890</td>
#       <td>0.109375</td>
#       <td>0.145739</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.255469</td>
#       <td>0.183330</td>
#       <td>115.625000</td>
#       <td>93.000000</td>
#       <td>250.000000</td>
#       <td>0.000000</td>
#       <td>115.625000</td>
#       <td>93.000000</td>
#       <td>250.000000</td>
#       <td>0.002733</td>
#       <td>0.121875</td>
#       <td>0.120775</td>
#       <td>0.117188</td>
#       <td>0.063002</td>
#       <td>0.016406</td>
#       <td>0.068276</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.232031</td>
#       <td>0.100490</td>
#       <td>111.875000</td>
#       <td>90.000000</td>
#       <td>350.000000</td>
#       <td>0.031250</td>
#       <td>104.193542</td>
#       <td>90.000000</td>
#       <td>118.000000</td>
#       <td>0.002213</td>
#       <td>0.091875</td>
#       <td>0.113980</td>
#       <td>0.140156</td>
#       <td>0.036863</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.234062</td>
#       <td>0.118744</td>
#       <td>114.937500</td>
#       <td>74.000000</td>
#       <td>237.000000</td>
#       <td>0.000000</td>
#       <td>114.937500</td>
#       <td>74.000000</td>
#       <td>237.000000</td>
#       <td>0.002361</td>
#       <td>0.101250</td>
#       <td>0.086098</td>
#       <td>0.121875</td>
#       <td>0.059484</td>
#       <td>0.010937</td>
#       <td>0.043039</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.345000</td>
#       <td>0.165225</td>
#       <td>119.375000</td>
#       <td>94.000000</td>
#       <td>350.000000</td>
#       <td>0.031250</td>
#       <td>111.935478</td>
#       <td>94.000000</td>
#       <td>143.000000</td>
#       <td>0.002152</td>
#       <td>0.160625</td>
#       <td>0.125850</td>
#       <td>0.140625</td>
#       <td>0.036890</td>
#       <td>0.043750</td>
#       <td>0.076990</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.281406</td>
#       <td>0.175315</td>
#       <td>112.281250</td>
#       <td>88.000000</td>
#       <td>137.000000</td>
#       <td>0.000000</td>
#       <td>112.281250</td>
#       <td>88.000000</td>
#       <td>137.000000</td>
#       <td>0.002361</td>
#       <td>0.133750</td>
#       <td>0.125016</td>
#       <td>0.131250</td>
#       <td>0.050402</td>
#       <td>0.016406</td>
#       <td>0.068276</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.391875</td>
#       <td>0.225612</td>
#       <td>115.656250</td>
#       <td>90.000000</td>
#       <td>350.000000</td>
#       <td>0.031250</td>
#       <td>108.096771</td>
#       <td>90.000000</td>
#       <td>128.000000</td>
#       <td>0.002312</td>
#       <td>0.227812</td>
#       <td>0.168446</td>
#       <td>0.131250</td>
#       <td>0.050402</td>
#       <td>0.032812</td>
#       <td>0.069398</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.230938</td>
#       <td>0.136757</td>
#       <td>125.000000</td>
#       <td>93.000000</td>
#       <td>350.000000</td>
#       <td>0.062500</td>
#       <td>110.000008</td>
#       <td>93.000000</td>
#       <td>141.000000</td>
#       <td>0.002462</td>
#       <td>0.094219</td>
#       <td>0.101267</td>
#       <td>0.131250</td>
#       <td>0.050402</td>
#       <td>0.005469</td>
#       <td>0.030936</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.335625</td>
#       <td>0.190159</td>
#       <td>110.000000</td>
#       <td>87.000000</td>
#       <td>128.000000</td>
#       <td>0.000000</td>
#       <td>110.000000</td>
#       <td>87.000000</td>
#       <td>128.000000</td>
#       <td>0.002384</td>
#       <td>0.133281</td>
#       <td>0.116575</td>
#       <td>0.131250</td>
#       <td>0.050402</td>
#       <td>0.071094</td>
#       <td>0.087323</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.314844</td>
#       <td>0.227947</td>
#       <td>111.500000</td>
#       <td>90.000000</td>
#       <td>176.000000</td>
#       <td>0.000000</td>
#       <td>111.500000</td>
#       <td>90.000000</td>
#       <td>176.000000</td>
#       <td>0.002219</td>
#       <td>0.150000</td>
#       <td>0.145912</td>
#       <td>0.126563</td>
#       <td>0.055335</td>
#       <td>0.038281</td>
#       <td>0.073502</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.402031</td>
#       <td>0.181839</td>
#       <td>104.718750</td>
#       <td>84.000000</td>
#       <td>127.000000</td>
#       <td>0.000000</td>
#       <td>104.718750</td>
#       <td>84.000000</td>
#       <td>127.000000</td>
#       <td>0.002345</td>
#       <td>0.202812</td>
#       <td>0.159039</td>
#       <td>0.150000</td>
#       <td>0.000000</td>
#       <td>0.049219</td>
#       <td>0.091468</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.264063</td>
#       <td>0.123499</td>
#       <td>106.281250</td>
#       <td>78.000000</td>
#       <td>137.000000</td>
# Streaming output truncated to the last 5000 lines.
# 0.25 : Describe Melilotus indicus : {"color": "Vibrant violet-blue", "inflorescencetype": "Raceme", "inflorescence_description": "Compact racemes with distinct, crescere along branching stems.", "flower_arrangement": "Flowers clustered along a dense, ascending stalk structure.", "flower_density": "Very dense", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.95 : Describe Melilotus indicus : {"color": "Vibrant violet-blue", "inflorescencetype": "Raceme", "inflorescence_description": "Compact racemes with distinct, nodding, individual flowers.", "flower_arrangement": "Flowers closely packed on a slender stem.", "flower_density": "Tightly on raceme", "species": "Lupinus polyphyllus", "family": "Fabaceae", "genus": "Lupinus"}
# 0.95 : Describe Melilotus indicus : {"color": "Vibrant violet-blue", "inflorescencetype": "Raceme", "inflorescence_description": "Compact, robust-racemes with abundant flowers.", "flower_arrangement": "Flowers clustered at heavily leaf-gastelong upper nodes.", "flower_density": "Very dense", "species": "Lupinus polyphyllus", "family": "Fabaceae", "genus": "Lupinus"}
# 0.95 : Describe Melilotus indicus : {"color": "Vibrant Yellow", "inflorescencetype": "Capitulum", "inflorescence_description": "Well-formed clusters, emerging from leaf axils.", "flower_arrangement": "Typically eight bright ray florets around a central disc.", "flower_density": "Clusters, clearly visible and distinct.", "species": "Tagetes tenuifolia", "family": "Asteraceae", "genus": "Tagetes"}
# 0.65 : Describe Melilotus indicus : {"color": "Vibrant Yellow", "inflorescencetype": "Capitulum", "inflorescence_description": "Well-formed clusters at racemes and axillary.", "flower_arrangement": " clusters at leaf axils", "flower_density": " clusters", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.95 : Describe Melilotus indicus : {"color": "Vibrant violet-blue", "inflorescencetype": "Raceme", "inflorescence_description": "Compact, robust-racemes with abundant flowers.", "flower_arrangement": "Flowers clustered at racously nodes, often dense.", "flower_density": "Very dense", "species": "Lupinus polyphyllus", "family": "Fabaceae", "genus": "Lupinus"}
# 0.95 : Describe Melilotus indicus : {"color": "Vibrant violet-blue", "inflorescencetype": "Raceme", "inflorescence_description": "Compact, robust-racemes with abundant flowers.", "flower_arrangement": "Flowers clustered at racously nodes, often tightly matted.", "flower_density": "Very dense", "species": "Lupinus polyphyllus", "family": "Fabaceae", "genus": "Lupinus"}
# 0.95 : Describe Melilotus indicus : {"color": "Vibrant magenta in full sun, appearing slightly cool-toned in diffuse light.", "inflorescencetype": "Capitulum", "inflorescence_description": "Capitulum, typically 2-3 ovoid heads at the stem tips, subtended by spiny bracts.", "flower_arrangement": "Capitula scattered along a long, slender stem, with flowers closed in leaf axils.", "flower_density": "Scattered", "species": "Cirsium dissectum", "family": "Asteraceae", "genus": "Cirsium"}
# 0.25 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": "A somewhat hazy, open cyme, with flowers present, some in bud.", "flower_arrangement": "Flowers appear softened, individual blooms on elongated stems.", "flower_density": "Slightly hazy", "species": "Lamium luteum", "family": "Lamiaceae", "genus": "Lamium"}
# 0.10 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": " A somewhat vibrant, well-जब lifted or slightly nodding cyme with flowers present.", "flower_arrangement": "Flowers on a nodding peduncle, emerging from a leaf nodding at the stem.", "flower_density": "Low", "species": "Lamium purpureum", "family": "Lamiaceae", "genus": "Lamium"}
# 0.25 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": "A somewhat hazy, open cyme, with flowers present, some slightly wilted.", "flower_arrangement": "Flowers in a slightly contested, open cluster.", "flower_density": "Slightly hazy", "species": "Lamium luteum", "family": "Lamiaceae", "genus": "Lamium"}
# 0.25 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": " Sprawling, multiple-flowered terminal cymes", "flower_arrangement": "Scattered, individual flowers long stems", "flower_density": "Sparse", "species": "Lamium galeobdolum", "family": "Lamiaceae", "genus": "Lamium"}
# 0.25 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": "A somewhat hazy, well-detached cyme", "flower_arrangement": "Flowers in a loose cluster with a stem.", "flower_density": "Moderate, somewhat hazy", "species": "Lamium galeobdolum", "family": "Lamiaceae", "genus": "Lamium"}
# 0.25 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": " Sprawling, multiple-flowered terminal cymes.", "flower_arrangement": "Flowers clustered in single axils.", "flower_density": "Scattered along sprawling stems.", "species": "Lamium galeobdolum", "family": "Lamiaceae", "genus": "Lamium"}
# 0.00 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": "A somewhat crowded cyme, with flowers under different stages of openness.", "flower_arrangement": "Flowers are at different stages, from waking up to fully open.", "flower_density": "Moderate", "species": "Acacia rich cobalt-purple", "family": "Fabaceae", "genus": "Acacia"}
# 0.65 : Describe Lamium amplexicaule : {"color": "Luminous yellow", "inflorescencetype": "Cyme", "inflorescence_description": "A close-up photograph capturing a single flower from a terminal cluster.", "flower_arrangement": "Vibrant yellow in detail, highlighting its symmetrical symmetry in bloom.", "flower_density": "High", "species": "Lactuca incita", "family": "Asteraceae", "genus": "Lactuca"}
# 0.85 : Describe Oncostema peruviana : {"color": "Greenish-red to orange-red", "inflorescencetype": "Solitary", "inflorescence_description": "Cup-shaped, slightly cool-toned, solitary.", "flower_arrangement": "Singly emerging from leaf bracts.", "flower_density": "Sparse, emerging", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Oncostema peruviana : {"color": "Greenish-red to orange-red", "inflorescencetype": "Solitary", "inflorescence_description": "Cup-shaped, slightly cool-toned with green tint.", "flower_arrangement": "Singly emerging from leaf bracts.", "flower_density": "Sufficiently dense, robust blooms.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Oncostema peruviana : {"color": "Vibrant scarlet-red up north, transitioning to a pale, greenish base.", "inflorescencetype": "Solitary", "inflorescence_description": "Large, showy solitary flowers from leaf axils, typically short.", "flower_arrangement": "Singly on short pedicels from leaf axils, often elongated stems.", "flower_density": "Low scattered, individual flowers distinct.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.45 : Describe Oncostema peruviana : {"color": "Vibrant scarlet-shaped heads", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower on a long pedicel (shortly attached) arising from leaf axil.", "flower_arrangement": "Flowers are not clustered in a terminal, branching cluster.", "flower_density": "Sparse, with flowers clearly visible and distinct from their neighboring flowers.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Oncostema peruviana : {"color": "Greenish-red to orange-red", "inflorescencetype": "Solitary", "inflorescence_description": "Cup-shaped, slightly cool-toned, vibrant.", "flower_arrangement": "Symmetrically open, appearing slightly less vivid.", "flower_density": "Moderate, robust growth.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.35 : Describe Oncostema peruviana : {"color": "Bright yellow-green", "inflorescencetype": "Axillary raceme", "inflorescence_description": "Abundant racemes form a purplish-pink raceme along the upper stem.", "flower_arrangement": "Flowers clustered along the upper stem, often near- pubescent.", "flower_density": "Abundant", "species": "Prosopis laPina", "family": "Fabaceae", "genus": "Prosopis"}
# 0.85 : Describe Oncostema peruviana : {"color": "Greenish-red to orange-red", "inflorescencetype": "Solitary", "inflorescence_description": "Newly, slightly color-distained, solitary flower.", "flower_arrangement": "Upright, solitary bloom, often newly closed.", "flower_density": "Low (generally)", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Oncostema peruviana : {"color": "Vibrant scarlet-red top-stem with fading yellow and newer green pods developing pods.", "inflorescencetype": "Solitary", "inflorescence_description": "Large, showy solitary flowers from leaf axils, typically short, verdacious.", "flower_arrangement": "Single flowers emerging from leaf axils.", "flower_density": "Low scattered, individual flowers clearly.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.35 : Describe Pyracantha koidzumii : {"color": "Punica granatum", "inflorescencetype": "Solitary", "inflorescence_description": "Single, prominent flowers from leaf axils.", "flower_arrangement": "Solitary in leaf axils, arising from leaf axils.", "flower_density": "Low, but prominent flowers on bright, succulent stems.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.45 : Describe Pyracantha koidzumii : {"color": "Pendant, often solitary", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower emerging from leaf axil.", "flower_arrangement": " singly axillary", "flower_density": "Pendant, often solitary,", "species": "Daphne striata", "family": "Thymelaeaceae", "genus": "Daphne"}
# 0.85 : Describe Pyracantha koidzumii : {"color": "Pendant, often solitary lime-green", "inflorescencetype": "Solitary", "inflorescence_description": "Pendant, often solitary vine-like.", "flower_arrangement": "Solitary flowers emerging from leaf axils.", "flower_density": "Solitary, scattered flowers.", "species": "Daphne striata", "family": "Thymelaeaceae", "genus": "Daphne"}
# 0.35 : Describe Pyracantha koidzumii : {"color": "Pendant, often solitary", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower emerging from leaf axil.", "flower_arrangement": " singly axillary", "flower_density": "Pendant pylon", "species": "Daphne striata", "family": "Thymelaeaceae", "genus": "Daphne"}
# 0.75 : Describe Pyracantha koidzumii : {"color": "Pendant, often solitary light greenish-red", "inflorescencetype": "Solitary", "inflorescence_description": "Solitary, long-stalked flowers.", "flower_arrangement": "Solitary, arising from leaf axils.", "flower_density": "Scattered, long flowering stems.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.45 : Describe Pyracantha koidzumii : {"color": "Pendant, often solitary", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower emerging from leaf axil.", "flower_arrangement": "Emergence from leaf axil.", "flower_density": "Pendant", "species": "Daphne striata", "family": "Thymelaeaceae", "genus": "Daphne"}
# 0.45 : Describe Pyracantha koidzumii : {"color": "Punica granatum", "inflorescencetype": "Solitary", "inflorescence_description": "Single, prominent flowers from leaf axils.", "flower_arrangement": "Solitary, arising from leaf axils.", "flower_density": "Sparse", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.35 : Describe Pyracantha koidzumii : {"color": "Punica granatum", "inflorescencetype": "Solitary", "inflorescence_description": "Small, neat single flower on a long pedicel.", "flower_arrangement": "From leaf axil or long pedicel, one flower per scape.", "flower_density": "Sparse, but can form dense, berths on a compact system.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.65 : Describe Trifolium angustifolium : {"color": "Vivid yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Vibrant yellow, directly emerging from a leaf axil.", "flower_arrangement": "Typical four-winged (dichasial) head, clearly defined.", "flower_density": "Dense cluster on a short peduncle.", "species": "Trifolium micranthum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium angustifolium : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often long, fuzzy in dense.", "flower_arrangement": "Tightly packed, spirally arranged florets.", "flower_density": "Very dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium angustifolium : {"color": "Vivid yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "A compact, rounded head of many small flowers, slightly nodding.", "flower_arrangement": "Axillary raceme, dense cluster of blooms.", "flower_density": "Very high, almost a solid yellow mass.", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.95 : Describe Trifolium angustifolium : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often slightly lax", "flower_arrangement": "Tightly clusters at nodes, but individual flowers clearly distinct.", "flower_density": "High", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium angustifolium : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often dense", "flower_arrangement": "Tightly cluster of flowers, slightly nodding", "flower_density": "High, newly opening, tightly cluster", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium angustifolium : {"color": "Vivid yellow", "inflorescencetype": "Head (Head-like)", "inflorescence_description": "A dense, rounded head of many small flowers, on a long, slender peduncle.", "flower_arrangement": "A compact cluster of heads at the stem, often appearing in clusters.", "flower_density": "Dense", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Trifolium angustifolium : {"color": "Vibrant yellow", "inflorescencetype": "Head (Head-like raceme)", "inflorescence_description": "Dense, head-like raceme, often dense", "flower_arrangement": "Tightly clusters along the central axis", "flower_density": "High, almost solid yellow", "species": "Trifolium aureum", "family": "Fabaceae", "genus": "Trifolium"}
# 0.65 : Describe Trifolium angustifolium : {"color": "Vivid yellow", "inflorescencetype": "Head (Head-like)", "inflorescence_description": "Small, dense, multiple heads are visible on a single, heavily cluster!", "flower_arrangement": "A multitude of small heads visible on a densely packed individual plant colony.", "flower_density": "High (Head)", "species": "Trifolium tetrapens", "family": "Fabaceae", "genus": "Trifolium"}
# 0.85 : Describe Sedum rupestre : {"color": "A mix of open flowers, turgid lower leaves with purplish tinge.", "inflorescencetype": "Cyme", "inflorescence_description": "A diffuse terminal cyme with flowers at different stages from bud.", "flower_arrangement": "A small cluster of flowers holding flowers from leaf axils.", "flower_density": "A loose cluster", "species": "Sedum dasyphyllum", "family": "Crassulaceae", "genus": "Sedum"}
# 0.48 : Describe Sedum rupestre : {"color": "Bright Pinkish-Ophrys", "inflorescencetype": "Capitulum", "inflorescence_description": "Solitary, cool-toned heads, possibly greenish.", "flower_arrangement": "Ray florets slightly muted around a subtle brown core.", "flower_density": "Medium density", "species": "Cirsium graveolens", "family": "Asteraceae", "genus": "Cirsium"}
# 0.45 : Describe Sedum rupestre : {"color": "Bright Pinkish-O (Head Count)", "inflorescencetype": "Globose Head", "inflorescence_description": "A dense, rounded flower heads, very resilient in harsh, windy conditions.", "flower_arrangement": "A tight cluster of numerous small flowers, each on a short pedicel.", "flower_density": "High density", "species": "Trifolium lowe", "family": "Fabaceae", "genus": "Trifolium"}
# 0.45 : Describe Sedum rupestre : {"color": "A mix of open flowers and branching stems from a probable low growing environment.", "inflorescencetype": "Cyme", "inflorescence_description": "A low-growing, open cyme on a sprawling, sprawling plant low among trifoliate leaves.", "flower_arrangement": "Flowers sit on a short, slightly robust stem with flowers rising from a clump.", "flower_density": "Loosely clustered", "species": "Sedum dasyphyllum", "family": "Crassulaceae", "genus": "Sedum"}
# 0.25 : Describe Sedum rupestre : {"color": "A visual model on a plant growing in rocky crevice", "inflorescencetype": "Sedum", "inflorescence_description": "A low-growing seduction, with flowers facing slightly away from wind.", "flower_arrangement": "A low-growing seduction, with flowers scattered near the low cluster.", "flower_density": "Low", "species": "Sedum rupestre", "family": "Crassulaceae", "genus": "Sedum"}
# 0.45 : Describe Sedum rupestre : {"color": "A healthy, transplanted specimen growing in a rocky crevice.", "inflorescencetype": "Cyme", "inflorescence_description": "A dense, flowering field with individuals at different stages from bud.", "flower_arrangement": "A robust cluster where flowers are predominantly structed within mature, leaf-difficated stems.", "flower_density": "Dense", "species": "Sedum maritum", "family": "Crassulaceae", "genus": "Sedum"}
# 0.35 : Describe Sedum rupestre : {"color": "A clear, numerical-grid on a short, thick stem.", "inflorescencetype": "Cyme", "inflorescence_description": "A dense, on a short-fit cyme on a short stem.", "flower_arrangement": "Flowers are dense due to short upper blooming flowers.", "flower_density": "Dense", "species": "Sedum dasyphyllum", "family": "Crassulaceae", "genus": "Sedum"}
# 0.25 : Describe Sedum rupestre : {"color": "A smart adult-young plant with withering leaves on a young plant.", "inflorescencetype": "Cyme", "inflorescence_description": "A leaf-young cyme with a mix of open flowers and developing buds.", "flower_arrangement": "A delicate cluster where buds and flowers are nestled at the same table.", "flower_density": "Low cluster", "species": "Pelargonium graveolens", "family": "Geraniaceae", "genus": "Pelargonium"}
# 0.58 : Describe Ophrys speculum : {"color": "Vibrant scarlet-red with a crisp white lip, fresh nectar.", "inflorescencetype": "Solitary", "inflorescence_description": "Single flowers on long stalks, emerging from leaf axils.", "flower_arrangement": "Pendant, solitary flowers emerging from leaf axils.", "flower_density": "Low, emerging flowers.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.45 : Describe Ophrys speculum : {"color": "Vibrant scarlet-red with a crisp white lip, pristine", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower emerging from leaf axil or leaf cut.", "flower_arrangement": "Symmetrically open, solitary bloom, slightly nodding.", "flower_density": "Low, emerging solitary flower or multiple flowers.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.65 : Describe Ophrys speculum : {"color": "Vibrant scarlet-red with mixed petals, a few green sepals.", "inflorescencetype": "Solitary", "inflorescence_description": "A single, large flower emerging from a leaf axil.", "flower_arrangement": "Singly emerging from leaf axil.", "flower_density": "Low, emerging flowers.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.00 : Describe Ophrys speculum : {"color": "Vibrant green-purple spathes, greenish yellow labellum.", "inflorescencetype": "Spike", "inflorescence_description": "E surprisingly dense, 3-7 flowers along a robust stem.", "flower_arrangement": "Spirously arranged flowers, often slightly nodding.", "flower_density": "High dense for the species, 3-7 blooms.", "species": "Spike-0.5", "family": "Orchidaceae", "genus": "Spike-0.5", "family": "Orchidaceae", "genus": "Spike-0.5", "family": "Orchidaceae", "genus": "Spike-0.5", "family": "Orchidaceae", "genus": "Spike-0.5", "family": "Orchidaceae", "Lamiaceae": "Lamium galeobdolum", "วงศ์": "Lamiaceae", "genus": "Spike-0.5", "family": "Orchidaceae", "Lamiaceae": "Lamium galeobdolum", "วงศ์": "Lamium"}
# 0.45 : Describe Ophrys speculum : {"color": "Vibrant scarlet-red with petals close to the ground.", "inflorescencetype": "Solitary", "inflorescence_description": "A single flower is terminal on a long peduncle.", "flower_arrangement": "Solitary, prominently emerging from solitary bracts.", "flower_density": "Low (scattered stems) ", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.25 : Describe Ophrys speculum : {"color": "Vibrant scarlet-red with a prominent, dark purple (anti-sat)" "inflorescencetype": "Solitary", "inflorescence_description": "A single, large flower held on a slender pedicel (pedicel) just above the water surface.", "flower_arrangement": "A solitary flower emerges from a flat, submerged aquatic ball on its own stalk.", "flower_density": "Scattered", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.25 : Describe Ophrys speculum : {"color": "Overall impression hazy yellow-green", "inflorescencetype": "Solitary axillary", "inflorescence_description": "Scattered axillary, solitary flowers.", "flower_arrangement": "Singly borne from leaf axils.", "flower_density": "Scattered", "species": "Ophrys tenthredinifera", "family": "Oryantaceae", "genus": "Ophrys"}
# 0.65 : Describe Ophrys speculum : {"color": "Vibrant scarlet-red with a crisp white lip, fresh green tint.", "inflorescencetype": "Solitary", "inflorescence_description": "Single flower emerging from leaf axil on a long pedicel.", "flower_arrangement": "Pedicular pedition, one flower per leaf axil, arising from leaf axil.", "flower_density": "Low (but individual flower clearly visible)", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# 0.85 : Describe Zamioculcas zamiifolia : {"color": "Dull yellow with somewhat frosted tips", "inflorescencetype": "Terminal raceme", "inflorescence_description": "Slightly somewhat elongated raceme, somewhat elongated inflorescence.", "flower_arrangement": "Slightly spaced along the central axis, with older flowers frow slightly frowed.", "flower_density": "Slightly dense", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.45 : Describe Zamioculcas zamiifolia : {"color": "Dull Yellow with Pinkish Tinge", "inflorescencetype": "Capitulum", "inflorescence_description": "Fewer, somewhat past-prime heads, mixed with scattered leaves.", "flower_arrangement": "Scattered, somewhat scattered heads, plants may be developing late season.", "flower_density": "Sparse heads", "species": "Fedia graciliflora", "family": "Caprifoliaceae", "genus": "Fedia"}
# 0.85 : Describe Zamioculcas zamiifolia : {"color": "Dull yellow with somewhat or browning edges", "inflorescencetype": "Terminal raceme", "inflorescence_description": "Very short, somewhat sparse raceme, appearing slightly elongated.", "flower_arrangement": "Flowers closely spaced, but with gaps.", "flower_density": "Sparse, very short flower or browning tips.", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.85 : Describe Zamioculcas zamiifolia : {"color": "Dull yellow with somewhat wilted appearance", "inflorescencetype": "Terminal raceme", "inflorescence_description": "Slender, somewhat elongated raceme, slightly drooping.", "flower_arrangement": "Flowers closely arranged on raceme, slightly drooping.", "flower_density": "Slightly dense", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.00 : Describe Zamioculcas zamiifolia : {"color": "Dull yellow-brown", "inflorescencetype": "Fழை", "inflorescence_description": "Fழை somewhat elongated, fading yellow, faded flowers.", "flower_arrangement": "Flowers closely along theழை, closely packed, often slightly discolored.", "flower_density": "Fழை closely)", "species": "Crotalaria polysperma", "family": "Fabaceae", "genus": "Crotalaria"}
# 0.85 : Describe Zamioculcas zamiifolia : {"color": "Dull white", "inflorescencetype": "Globose head", "inflorescence_description": "Subt moderately weathered, soft-looking, loose heads.", "flower_arrangement": "Flowers irregularly distributed along uneven stems.", "flower_density": "Slightly loose", "species": "Morinda citrifolia", "family": "Rubiaceae", "genus": "Morinda"}
# 0.45 : Describe Zamioculcas zamiifolia : {"color": "Dull Yellow with Pinkish Hues", "inflorescencetype": "Capitulum", "inflorescence_description": "Fewer, somewhat scattered heads, plant stress.", "flower_arrangement": " scattered heads, individual sepals more defined.", "flower_density": "Sparse, fewer heads per plant.", "species": "Fedia graciliflora", "family": "Caprifoliaceae", "genus": "Fedia"}
# 0.45 : Describe Zamioculcas zamiifolia : {"color": "Dull white, appearing muted in low light", "inflorescencetype": "Terminal panicle", "inflorescence_description": "Compact panicle, often slightly elongated stems due to stress.", "flower_arrangement": "Slightly dense flowers, often aggregated nodes, each tipped slightly.", "flower_density": "Moderate", "species": "Phyllanthus acid", "family": "Phyllanthaceae", "genus": "Phyllanthus"}
# 0.45 : Describe Hippophae rhamnoides : {"color": "Bright orange", "inflorescencetype": "Solitary", "inflorescence_description": "Solitary, vibrant orange-red, showing axillary flowers.", "flower_arrangement": " singly leaf-bracted along length.", "flower_density": "Moderate, scattered along elongated stem.", "species": "Punica granatum", "family": "Lythraceae", "genus": "Punica"}
# ...
#    2236         else:
# -> 2237             return inner_training_loop(
#    2238                 args=args,
#    2239                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/accelerate/utils/memory.py in decorator(*args, **kwargs)
#     172                 raise RuntimeError("No executable batch size found, reached zero.")
#     173             try:
# --> 174                 return function(batch_size, *args, **kwargs)
#     175             except Exception as e:
#     176                 if should_reduce_batch_size(e):
#
# /usr/local/lib/python3.11/dist-packages/unsloth_zoo/compiler.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/_utils.py in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# /usr/local/lib/python3.11/dist-packages/trl/extras/profiling.py in wrapper(self, *args, **kwargs)
#      96     def wrapper(self, *args, **kwargs):
#      97         with profiling_context(self, func.__name__):
# ---> 98             return func(self, *args, **kwargs)
#      99
#     100     return wrapper
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in _prepare_inputs(self, generation_batch)
#    1632             if self._step % generate_every == 0 or self._buffered_inputs is None:
#    1633                 # self._buffered_inputs=None can occur when resuming from a checkpoint
# -> 1634                 generation_batch = self._generate_and_score_completions(generation_batch)
#    1635                 generation_batch = shuffle_tensor_dict(generation_batch)
#    1636                 self._buffered_inputs = split_tensor_dict(generation_batch, self.args.steps_per_generation)
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in _generate_and_score_completions(self, inputs)
#    1825                     else nullcontext()
#    1826                 ):
# -> 1827                     prompt_completion_ids = unwrapped_model.generate(
#    1828                         prompt_ids, attention_mask=prompt_mask, generation_config=self.generation_config
#    1829                     )
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/rl.py in generate_with_clone(*args, **kwargs)
#      68             original_generate = unwrapped_model.generate
#      69             def generate_with_clone(*args, **kwargs):
# ---> 70                 out = original_generate(*args, **kwargs)
#      71                 if isinstance(out, torch.Tensor):
#      72                     return out.clone()
#
# /usr/local/lib/python3.11/dist-packages/peft/peft_model.py in generate(self, *args, **kwargs)
#    1971                 with self._enable_peft_forward_hooks(*args, **kwargs):
#    1972                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1973                     outputs = self.base_model.generate(*args, **kwargs)
#    1974             else:
#    1975                 outputs = self.base_model.generate(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/vision.py in unsloth_base_fast_generate(self, *args, **kwargs)
#     236         kwargs.pop("prompt_lookup_num_tokens", None)
#     237         with torch.inference_mode(), autocaster:
# --> 238             output = self._old_generate(*args, **kwargs)
#     239     finally:
#     240         pass
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2631
#    2632             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2633             result = self._sample(
#    2634                 input_ids,
#    2635                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3615                 is_prefill = False
#    3616             else:
# -> 3617                 outputs = model_forward(**model_inputs, return_dict=True)
#    3618
#    3619             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /content/unsloth_compiled_cache/unsloth_compiled_module_gemma3n.py in forward(self, input_ids, pixel_values, input_features, attention_mask, input_features_mask, position_ids, past_key_values, token_type_ids, cache_position, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, logits_to_keep, **lm_kwargs)
#    1691         **lm_kwargs,
#    1692     ) -> Gemma3nCausalLMOutputWithPast:
# -> 1693         return Gemma3nForConditionalGeneration_forward(self, input_ids, pixel_values, input_features, attention_mask, input_features_mask, position_ids, past_key_values, token_type_ids, cache_position, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, logits_to_keep, **lm_kwargs)
#    1694
#    1695     def prepare_inputs_for_generation(
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     959         if return_dict_passed is not None:
#     960             return_dict = return_dict_passed
# --> 961         output = func(self, *args, **kwargs)
#     962         if not return_dict and not isinstance(output, tuple):
#     963             output = output.to_tuple()
#
# /content/unsloth_compiled_cache/unsloth_compiled_module_gemma3n.py in Gemma3nForConditionalGeneration_forward(self, input_ids, pixel_values, input_features, attention_mask, input_features_mask, position_ids, past_key_values, token_type_ids, cache_position, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, logits_to_keep, **lm_kwargs)
#    1495     )
#    1496
# -> 1497     outputs = self.model(
#    1498         input_ids=input_ids,
#    1499         pixel_values=pixel_values,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     959         if return_dict_passed is not None:
#     960             return_dict = return_dict_passed
# --> 961         output = func(self, *args, **kwargs)
#     962         if not return_dict and not isinstance(output, tuple):
#     963             output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gemma3n/modeling_gemma3n.py in forward(self, input_ids, pixel_values, input_features, attention_mask, input_features_mask, position_ids, past_key_values, token_type_ids, cache_position, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, **lm_kwargs)
#    2113             inputs_embeds = inputs_embeds.masked_scatter(special_audio_mask, audio_features)
#    2114
# -> 2115         outputs = self.language_model(
#    2116             input_ids=None,
#    2117             per_layer_inputs=per_layer_inputs,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     959         if return_dict_passed is not None:
#     960             return_dict = return_dict_passed
# --> 961         output = func(self, *args, **kwargs)
#     962         if not return_dict and not isinstance(output, tuple):
#     963             output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gemma3n/modeling_gemma3n.py in forward(self, input_ids, per_layer_inputs, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **kwargs)
#    1673             per_layer_input = per_layer_inputs[:, :, decoder_layer.layer_idx, :]
#    1674
# -> 1675             layer_outputs = decoder_layer(
#    1676                 hidden_states,
#    1677                 position_embeddings_global,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      92
#      93             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94         return super().__call__(*args, **kwargs)
#      95
#      96
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py in wrapped_func(*args, **kwargs)
#     170                 warnings.warn(message, FutureWarning, stacklevel=2)
#     171
# --> 172             return func(*args, **kwargs)
#     173
#     174         return wrapped_func
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gemma3n/modeling_gemma3n.py in forward(self, hidden_states, position_embeddings_global, position_embeddings_local, per_layer_input, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, **kwargs)
#    1434             position_embeddings = position_embeddings_global
#    1435
# -> 1436         attn, self_attn_weights = self.self_attn(
#    1437             hidden_states=active_prediction_normed,
#    1438             position_embeddings=position_embeddings,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /content/unsloth_compiled_cache/unsloth_compiled_module_gemma3n.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#    1118         **kwargs: Unpack[FlashAttentionKwargs],
#    1119     ) -> tuple[torch.Tensor, Optional[torch.Tensor], Optional[tuple[torch.Tensor]]]:
# -> 1120         return Gemma3nTextAttention_forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#    1121
#    1122
#
# /content/unsloth_compiled_cache/unsloth_compiled_module_gemma3n.py in Gemma3nTextAttention_forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#    1065
#    1066     attn_output = attn_output.reshape(*input_shape, -1).contiguous()
# -> 1067     attn_output = self.o_proj(attn_output)
#    1068     return attn_output, attn_weights
#    1069
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /content/unsloth_compiled_cache/Linear_peft_forward.py in unsloth_forward(self, x, *args, **kwargs)
#      54         result = self.base_layer(x, *args, **kwargs)
#      55     else:
# ---> 56         result = self.base_layer(x, *args, **kwargs)
#      57         torch_result_dtype = result.dtype
#      58
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 8. Save Model

# %%
# model.save_pretrained("gemma-3n")  # Local saving
# tokenizer.save_pretrained("gemma-3n")
# model.push_to_hub("HF_ACCOUNT/gemma-3", token = "...") # Online saving
# tokenizer.push_to_hub("HF_ACCOUNT/gemma-3", token = "...") # Online saving

model_save_path = f"gemma-3n-botanist-grpo6p"

#model.save_pretrained(output_dir)  # Local saving
#tokenizer.save_pretrained(output_dir)
#model.save_pretrained_merged(output_dir+"-merged", tokenizer)
#model.push_to_hub("mekpro/"+model_save_path, token = HF_TOKEN) # Online saving
#tokenizer.push_to_hub("mekpro/"+model_save_path, token = HF_TOKEN) # Online saving


model.push_to_hub_merged(
    repo_id="mekpro/"+model_save_path+"-merged",
    tokenizer=tokenizer,
    save_method="merged_16bit",
    token = HF_TOKEN
)

#model.push_to_hub_gguf(model_save_path+"-gguf", repo_id="mekpro/gemma-3n-e4b-botanist-gguf-grpo", quantization_type="q8_0", token=HF_TOKEN)
# Out:
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Successfully copied all 3 files from cache to mekpro/gemma-3n-botanist-grpo6p-merged.
# Downloading safetensors index for mekpro/gemma-3n-botanist-observe6-merged...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# Unsloth: Merging weights into 16bit:   0%|          | 0/3 [00:00<?, ?it/s]No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# Unsloth: Merging weights into 16bit:  33%|███▎      | 1/3 [00:21<00:42, 21.21s/it]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit:  67%|██████▋   | 2/3 [02:57<01:40, 100.87s/it]
# model-00003-of-00003.safetensors:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit: 100%|██████████| 3/3 [04:27<00:00, 89.07s/it]

# %% [markdown]
# ## 9. Test the Fine-tuned Model

# %%
def test_model(test_species: str):
    """Test the fine-tuned model with a sample species"""
    test_prompt = f"{INSTRUCTION_PROMPT}\n\nSpecies to observe: {test_species}"

    # Tokenize
    inputs = tokenizer(test_prompt, return_tensors="pt", truncation=True, max_length=MAX_SEQ_LENGTH)
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    # Generate
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=MAX_NEW_TOKENS,
            temperature=TEMPERATURE,
            top_p=TOP_P,
            do_sample=True,
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )

    # Decode
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Extract only the generated part
    response = response[len(test_prompt):].strip()

    print(f"Test Species: {test_species}")
    print(f"Model Response:\n{response}")

    # Evaluate with reward functions
    bot_reward = botanist_reward(response, test_species)
    fmt_reward = format_reward(response)

    print(f"\nBotanist Reward: {bot_reward}/100")
    print(f"Format Reward: {fmt_reward}/100")
    print(f"Combined Score: {BOTANIST_REWARD_WEIGHT * bot_reward + FORMAT_REWARD_WEIGHT * fmt_reward:.1f}/100")

# Test with a few species
test_species_list = unique_species[:3] if len(unique_species) >= 3 else unique_species
for species in test_species_list:
    test_model(species)
    print("\n" + "="*80 + "\n")
